# %%
#@ignore
import nbtof_base

# %%
#@advance
def test():
    pass

# %%
#@ignore
nbtof_base.nbtof_base(__vsc_ipynb_file__)
# Out:
# ('c:\\Users\\1618s\\OneDrive\\Programs\\04_tool\\function_maker\\sample_c.py',
#  None)
