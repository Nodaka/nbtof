# %%
#@advance
import nbtof_base
import nbtof_concat

# %%
#@param
output_py_file = 'base.py'
notebook_file = ['sample_a.ipynb', 'sample_b.ipynb']

# %%
with open(output_py_file, 'w') as f:
    pass

# %%
if type(notebook_file) == str:
    notebook_file = [notebook_file]

# %%
for notebook_file_name in notebook_file:
    func_file_path, _ = nbtof_base.nbtof_base(nb_path=notebook_file_name)
    nbtof_concat.nbtof_update_base(
        output_py_file,
        func_file_path)

# %%
#@return
output_py_file
# Out:
# 'base.py'

# %%
#@ignore
nbtof_base.nbtof_base(__vsc_ipynb_file__)
# Out:
# ('c:\\Users\\1618s\\OneDrive\\Programs\\04_tool\\function_maker\\nbtof_generate.py',
#  None)
