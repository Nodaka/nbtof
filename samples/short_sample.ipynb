# %%
#@ignore
import nbtof

# %%
#@param
a = 1
b = 1

# %%
c = a + b

# %%
#@return
c
# Out:
# 2

# %%
#@ignore
nbtof.nbtof_generate(
    output_py_file='output.py',
    notebook_file='short_sample.ipynb',
    )
# Out:
# 'output.py'
